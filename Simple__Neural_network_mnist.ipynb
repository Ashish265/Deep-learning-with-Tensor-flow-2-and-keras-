# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashish265/Deep-learning-with-Tensor-flow-2-and-keras-/blob/master/Simple__Neural_network_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# Network and training parameters

EPOCHS = 200
BATCH_SIZE = 128
VERBOSE =1
NB_CLASSES = 10
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2

# %%
# lOADING THE DATA  

mnist = keras.datasets.mnist

(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %%
# X_train is 60000 rows of 28x28 values; we --> reshape it to
# 60000 x 784

# %%
RESHAPED = 784

X_train = X_train.reshape(60000,RESHAPED)
X_test = X_test.reshape(10000,RESHAPED)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %%
X_train = X_train/255
X_test = X_test/255

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
# One-hot representation of the labels.
y_train = tf.keras.utils.to_categorical(y_train, NB_CLASSES)
y_test = tf.keras.utils.to_categorical(y_test, NB_CLASSES)

# %%
# Build the model

model = tf.keras.models.Sequential()

# %%
model.add(keras.layers.Dense(NB_CLASSES,input_shape= (RESHAPED,),name='dense_layer',activation='softmax'))

# %%
model.compile(optimizer = 'SGD',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,batch_size=BATCH_SIZE,epochs=EPOCHS,verbose=VERBOSE,validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/200
# 375/375 [==============================] - 1s 2ms/step - loss: 1.3678 - accuracy: 0.6740 - val_loss: 0.8853 - val_accuracy: 0.8312
# Epoch 2/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.7838 - accuracy: 0.8322 - val_loss: 0.6494 - val_accuracy: 0.8588
# Epoch 3/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.6359 - accuracy: 0.8533 - val_loss: 0.5554 - val_accuracy: 0.8712
# Epoch 4/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.5650 - accuracy: 0.8634 - val_loss: 0.5037 - val_accuracy: 0.8798
# Epoch 5/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.5220 - accuracy: 0.8700 - val_loss: 0.4703 - val_accuracy: 0.8849
# Epoch 6/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4925 - accuracy: 0.8753 - val_loss: 0.4469 - val_accuracy: 0.8881
# Epoch 7/200
# ...

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2776 - accuracy: 0.9215
# Test accuracy: 0.921500027179718
